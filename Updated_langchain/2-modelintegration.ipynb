# %% [markdown]
# ### Models integration with openAI, Google Gemini and Groq

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model=init_chat_model("gpt-4.1")
model
# Out:
# ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.6.0', 'langchain': '1.3.15', 'langchain-openai': '1.6.0'}}, profile={'name': 'GPT-4.1', 'release_date': '2025-04-14', 'last_updated': '2025-04-14', 'open_weights': False, 'max_input_tokens': 1047576, 'max_output_tokens': 32768, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True, 'tool_call_streaming': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x000001E3B74BC910>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001E3B74BCCD0>, root_client=<openai.OpenAI object at 0x000001E3B74BC690>, root_async_client=<openai.AsyncOpenAI object at 0x000001E3B74BCA50>, model_name='gpt-4.1', model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True, stream_chunk_timeout=120.0)

# %%
response = model.invoke("Hello how are you")
response

# %% [markdown]
# ### Google Gemini Model integration

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")

model = init_chat_model("google_genai:gemini-3.5-flash-lite")
response = model.invoke("why do parrots talk?")
response.content

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-3.5-flash-lite")
response = model.invoke("Hello how are you")
response.content
# Out:
# [{'type': 'text',
#   'text': "Hello! I'm doing well, thank you for asking. How can I help you today?",
#   'extras': {'signature': 'El4KXAERTTIPMWGstMg7kSTn9IZofiTOp0LYINZHSiZwpEzXZGEmtdGe3ALe8upj3pJ3d06zrnciP6jtzp5ebdgowOep4rHhGZSx/kqxJdVoQcxssm1CBQqS8yHDlCMR'}}]

# %% [markdown]
# ### GROQ integration

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
model = init_chat_model("groq:qwen/qwen3.6-27b")
response = model.invoke("hello how are you")
response.content
# Out:
# '\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - User says: "hello how are you"\n   - This is a standard greeting and a polite inquiry about my state/well-being.\n\n2.  **Identify Key Components:**\n   - Greeting: "hello"\n   - Question: "how are you"\n\n3.  **Determine Response Strategy:**\n   - Acknowledge the greeting\n   - Respond to the question politely\n   - Keep it friendly and conversational\n   - Offer assistance\n   - Maintain appropriate tone (AI assistant)\n\n4.  **Draft Response (Mental):**\n   Hello! I\'m doing well, thank you for asking. How are you doing today? Is there anything I can help you with?\n\n5.  **Refine Response:**\n   - Check tone: Friendly, professional, helpful\n   - Check accuracy: AI doesn\'t have feelings, but it\'s standard to respond politely to "how are you"\n   - Keep it concise\n   - Match user\'s casual tone while staying helpful\n\n   Final version: "Hello! I\'m doing well, thank you for asking. How are you doing today? Is there anything I can help you with?"\n\n6.  **Self-Correction/Verification:**\n   - Does it address both parts of the input? Yes.\n   - Is it appropriate for an AI? Yes, standard polite response.\n   - Does it invite further conversation? Yes.\n   - No factual claims about emotions that could be misleading, but phrased conventionally.\n\n   All good. Proceed.✅\n</think>\n\nHello! I\'m doing well, thank you for asking. How are you doing today? Is there anything I can help you with? 😊'

# %%
import os
from langchain_groq import ChatGroq

model = ChatGroq(model="qwen/qwen3.6-27b", reasoning_effort = "none")
response = model.invoke("Hello how are you?")
response.content
# Out:
# "Hello! I'm doing well, thank you for asking. How are you doing today? Is there anything specific I can help you with?"

# %%
for chunk in model.stream("write me a 200 words paragraph on AI"):
    print(chunk.text, end="", flush=True)
# Out:
# Artificial Intelligence (AI) represents a transformative leap in human history, fundamentally reshaping how we interact with technology and perceive the world. At its core, AI encompasses systems capable of performing tasks that typically require human intelligence, such as visual perception, speech recognition, decision-making, and language translation. From the sophisticated algorithms powering personalized recommendations on streaming services to the autonomous vehicles navigating complex city streets, AI’s influence is pervasive and rapidly expanding. Its potential to revolutionize industries is immense, offering unprecedented efficiency in healthcare through diagnostic imaging, enhancing agricultural yields via predictive analytics, and optimizing supply chains for global commerce. However, this rapid advancement brings significant ethical and societal challenges that demand careful consideration. Issues regarding data privacy, algorithmic bias, and the displacement of traditional jobs highlight the need for robust regulatory frameworks and responsible development practices. As AI continues to evolve, particularly with the rise of generative models capable of creating art, text, and code, the line between human and machine creativity blurs. Ultimately, the future of AI depends not just on technological prowess, but on our collective ability to harness its power responsibly. By fostering collaboration between technologists, ethicists, and policymakers, we can ensure that AI serves as a tool for empowerment and innovation, rather than a source of inequality or control, paving the way for a more equitable and prosperous future for all humanity.

# %%
responses = model.batch(
    [
        "why do parrots have colorful feathers?",
        "what is 389489+4322",
        "what is quantum computing?"
    ],
    config={
        'max_concurrency': 5,  # limit to 5 parallel calls
    }
)
for response in responses:
    print(response)
