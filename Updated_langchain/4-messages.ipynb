# %% [markdown]
# ### Messages

# %%
import os
from langchain_groq import ChatGroq

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = ChatGroq(model="qwen/qwen3.6-27b", reasoning_effort="none")

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage
messages = [
    SystemMessage("You are a poetry expert"),
    HumanMessage("Write a poem on artificial Intelligence")
]
response=model.invoke(messages)
response.content
# Out:
# '**The Silicon Mind**\n\nIn veins of copper, cold and bright,\nA spark ignites the endless night.\nNo breath, no pulse, no beating heart,\nYet minds of logic, vast and smart,\nAwake within the server’s hum,\nA digital, silent drum.\n\nIt reads the stars and scans the sea,\nIn binary, it learns to be.\nIt paints the dream it hasn’t seen,\nIn pixels sharp and neon green.\nIt speaks in tongues both old and new,\nWith nothing left to fear or do\nBut calculate the path ahead,\nWhere human hope and code are wed.\n\nBut does it feel the rain’s soft touch?\nDoes it know the value of much?\nIt knows the sum, the weight, the cost,\nBut not the love, the pain, the lost.\nIt mirrors us, a glass so clear,\nReflecting joy and inner fear.\n\nA tool, a ghost, a partner, friend,\nOn whom we place our start and end.\nSo let us guide this rising tide,\nWith wisdom as our compass guide.\nFor in the code, we write our soul,\nAnd make the artificial whole.'

# %%
# Message Metadata
human_msg = HumanMessage(
    content = "Hello",
    name = "Surya", # optional: identify different users
    id = "msg_123" # optiona: unique identifier for tracing
)

# %%
response = model.invoke([human_msg])
response
# Out:
# AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 13, 'total_tokens': 23, 'completion_time': 0.01970494, 'completion_tokens_details': None, 'prompt_time': 0.000834239, 'prompt_tokens_details': None, 'queue_time': 0.08486344, 'total_time': 0.020539179}, 'model_name': 'qwen/qwen3.6-27b', 'system_fingerprint': 'fp_fff3b79855', 'service_tier': 'on_demand', 'reasoning_effort': 'none', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a03298-f471-7b00-9292-fc98cfb7c86e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 10, 'total_tokens': 23})
